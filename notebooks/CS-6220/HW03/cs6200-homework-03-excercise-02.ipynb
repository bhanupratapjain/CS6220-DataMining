# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
import numpy as np

plt.style.use('ggplot')
# %matplotlib inline

# %%
X, label = make_moons(n_samples=200, noise=0.1, random_state=19)
print X.shape
# Out:
# (200, 2)

# %%
model = DBSCAN(eps=0.25, min_samples=12).fit(X)
print model
# Out:
# DBSCAN(algorithm='auto', eps=0.25, leaf_size=30, metric='euclidean',
#     min_samples=12, p=None, random_state=None)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sctr = ax.scatter(X[:, 0], X[:, 1], c=model.labels_, s=140, alpha=0.9,
                 cmap=plt.cm.Set1)
# fig.show()

# %%
X1 = [
    [0,1],
    [5,2],
    [2,3],
    [6,1],
[10,2],
[0,6],
[3,4],
[6,3],
[0,7],
[7,2],
[1,2]
]

# %%
X1 = np.array(X1)

# %%
model1 = DBSCAN(eps=2.82842712475, min_samples=4).fit(X1)
print X1.shape
print model1
print model1.labels_
fig, ax = plt.subplots(figsize=(10, 8))
sctr = ax.scatter(X1[:, 0], X1[:, 1],s=140, alpha=0.9,)
# Out:
# (11, 2)
# DBSCAN(algorithm='auto', eps=2.82842712475, leaf_size=30, metric='euclidean',
#     min_samples=4, p=None, random_state=None)
# [ 0  0  0  0 -1 -1  0  0 -1  0  0]

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sctr = ax.scatter(X1[:, 0], X1[:, 1], c=model1.labels_, s=140, alpha=0.9,
                 cmap=plt.cm.Set1)
